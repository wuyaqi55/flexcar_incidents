# %%
import json
s = "{\"id\":\"4bd8fa36-536a-11f0-b61d-161ed24a9db1\",\"fields\":[\"seasoning_3month_incident_Ind.0\",\"seasoning_3month_incident_Ind.1\"],\"score\":[[\"0.9967961\",\"0.003203903\"]]}"
json.loads(s)
# Out:
# {'id': '4bd8fa36-536a-11f0-b61d-161ed24a9db1',
#  'fields': ['seasoning_3month_incident_Ind.0',
#   'seasoning_3month_incident_Ind.1'],
#  'score': [['0.9967961', '0.003203903']]}

# %%
import pandas as pd

table = pd.read_csv('../data/sample_data.csv')

# %%
table
# Out:
#                           Subscriber Id  3_month_loss  6_momth_loss  \
# 0  199296b7-4255-48b3-bce4-0bb1164bb39c     -16232.71     -16234.46
# 1  ce23a477-e184-434f-8099-1cf77ff57a3f      -1021.69      -8599.15
# 2  129b85ae-e53b-483c-b16c-625fe5af1ca3      -4398.70      -6615.54
# 3  2a95800b-3a8d-4513-b683-68de5e8507b8          0.00      -6495.04
# 4  a3b5875d-10ed-464b-962c-f238bab9828f      -5740.94      -5740.94
#
#    9_month_loss  12_month_loss  default_ind  Created At  Default_Ind  \
# 0     -16234.46      -16234.46            1  2024-02-28            0
# 1      -8599.15       -8599.15            1  2024-04-10            1
# 2      -6616.13       -6616.13            1  2024-08-20            1
# 3      -6495.04       -6495.04            1  2024-02-29            1
# 4      -5740.94       -5740.94            1  2024-07-16            1
#
#    Prior Auto All in Good Standing  Prior Auto Repossession  ...  \
# 0                                1                        0  ...
# ...

# %%
l = list(table.columns)

# %%
l[:200]
# Out:
# ['Subscriber Id',
#  '3_month_loss',
#  '6_momth_loss',
#  '9_month_loss',
#  '12_month_loss',
#  'default_ind',
#  'Created At',
#  'Default_Ind',
#  'Prior Auto All in Good Standing',
#  'Prior Auto Repossession',
#  'Prior Auto Chargeoff',
#  'Prior Auto Delinquent Event',
#  'Prior CC Chargeoff',
#  'Prior CC All in Good Standing',
#  'Prior CC Chargeoff or Prior Auto Repo',
#  'Prior CC Chargeoff or Prior Auto Chargeoff',
#  'Any Prior Delinquent Event',
#  'Total Debt Load',
#  'Risk Inform Address Flags Governmental Address',
#  'Risk Inform Address Flags Camp Site Address',
#  'Risk Inform Address Flags Check Cashing Service Address',
#  'Risk Inform Address Flags Correctional Institution Address',
#  'Risk Inform Address Flags Credit Correction Address',
#  'Risk Inform Address Flags Hotel or Temporary Address',
#  'Risk Inform Address Flags Mail Service Address',
#  'Risk Inform Address Flags Nursing Home Address',
# ...
