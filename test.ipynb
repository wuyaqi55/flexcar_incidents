# %%
import pandas as pd

table = pd.read_csv('../data/sample_data.csv')

# %%
table.shape
# Out:
# (5, 1134)

# %%
l = list(table.columns)

# %%
l[:200]
# Out:
# ['Subscriber Id',
#  '3_month_loss',
#  '6_momth_loss',
#  '9_month_loss',
#  '12_month_loss',
#  'default_ind',
#  'Created At',
#  'Default_Ind',
#  'Prior Auto All in Good Standing',
#  'Prior Auto Repossession',
#  'Prior Auto Chargeoff',
#  'Prior Auto Delinquent Event',
#  'Prior CC Chargeoff',
#  'Prior CC All in Good Standing',
#  'Prior CC Chargeoff or Prior Auto Repo',
#  'Prior CC Chargeoff or Prior Auto Chargeoff',
#  'Any Prior Delinquent Event',
#  'Total Debt Load',
#  'Risk Inform Address Flags Governmental Address',
#  'Risk Inform Address Flags Camp Site Address',
#  'Risk Inform Address Flags Check Cashing Service Address',
#  'Risk Inform Address Flags Correctional Institution Address',
#  'Risk Inform Address Flags Credit Correction Address',
#  'Risk Inform Address Flags Hotel or Temporary Address',
#  'Risk Inform Address Flags Mail Service Address',
#  'Risk Inform Address Flags Nursing Home Address',
# ...
