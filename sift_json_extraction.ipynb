# %% [markdown]
# ## Samba

# %% [markdown]
# ## Sift

# %%
import pandas as pd
import json
import warnings
import math 
warnings.filterwarnings("ignore")

# load data
data = pd.read_csv('../data/sift.csv').dropna(subset=['Decision Reasons'])

# data = data.head(2) # for testing


def try_float_or_split(s):
    if s is None:
        return
    if isinstance(s, float) and math.isnan(s):
        return None
    
    try:
        return float(s)  # try convert whole string to float
    
    except (ValueError, TypeError):     
        # If not convertible, split and return parts for further processing
        if isinstance(s, str):
            parts = s.strip().split(' ')
            if parts[-1] in ['km/h','km', 'USD', 'hours', 'ms']:
                return float(parts[0])
            if parts[-1] == 'days':
                return float(parts[0])*24
            if parts[-1] == 'minutes':
                return float(parts[0])/60
            else:
                return s
 
        else:
            return None 

## get all possible value for the 'name' field in response -- attributes
def find_all_names(obj, name_values):
    if isinstance(obj, dict):
        for k, v in obj.items():
            if k == 'name':
                name_values.add(v)
            else:
                find_all_names(v, name_values)
    elif isinstance(obj, list):
        for item in obj:
            find_all_names(item, name_values)

attributes = set()

for index, value in data['Decision Reasons'].items():
    if not pd.isna(value):
        try:
            parsed_value = json.loads(value)  # <-- parse JSON string to Python object
            find_all_names(parsed_value, attributes)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON at index {index}")


## extact value for each attribute
def find_value(obj, target_name):
    if isinstance(obj, dict):
        # Check for keys safely
        if 'name' in obj and obj['name'] == target_name:
            return obj.get('value')
        # Recursively check values inside dict
        for v in obj.values():
            found = find_value(v, target_name)
            if found is not None:
                return found
    elif isinstance(obj, list):
        for item in obj:
            found = find_value(item, target_name)
            if found is not None:
                return try_float_or_split(found)
    return None


for name in attributes:
    data[name] = data['Decision Reasons'].apply(
        lambda x: find_value(json.loads(x), name) if pd.notna(x) else None
    )

# %% [markdown]
# ## indicators
# payment failure, tow/repo, accident

# %%
data.isna().mean().sort_values(ascending=False).to_csv('../data/missing.csv')

# %%
# ## check if API return chargeback information
# my_string = ''
# for value in data['Decision Reasons']:
#     if not pd.isna(value):
#         my_string = my_string+value
# my_string

# %%
# data.to_csv('../data/processed_sift.csv')

# %%
# attributes

# %%
indicators = pd.read_csv('../data/payment_failure_indicators.csv')

# %%
def process_time_interval_data(s):
    if not isinstance(s, str):
        return None  # or np.nan
    parts = s.strip().split(' ')
    if len(parts) != 2:
        return None
    value, unit = parts
    try:
        val = float(value)
    except ValueError:
        return None

    if unit == 'days':
        return val * 24
    elif unit == 'hours':
        return val
    elif unit == 'minutes':
        return val / 60
    else:
        return None


for attri in attributes:
    # print(f"Processing column {attri}")
    num_data = pd.to_numeric(data[attri], errors='coerce')

    if num_data.notna().all():
        # Already fully numeric, assign back
        data[attri] = num_data
        continue

    # Not fully numeric, try special handling:
    unique_vals = data[attri].dropna().unique()
    if len(unique_vals) > 5:
        sample_val = unique_vals[0] if isinstance(unique_vals[0], str) else str(unique_vals[0])
        last_word = sample_val.strip().split(' ')[-1]

        if last_word == 'km':
            data[attri] = data[attri].astype(str).map(lambda x: x.strip().split(' ')[0])
            data[attri] = pd.to_numeric(data[attri], errors='coerce')

        elif last_word in ['days', 'hours', 'minutes']:
            data[attri] = data[attri].map(process_time_interval_data)
            data[attri] = pd.to_numeric(data[attri], errors='coerce')

        else:
            data[attri] = pd.to_numeric(data[attri], errors='ignore')
            print(f"Column {attri} has unknown unit '{last_word}'")

    # else:
    #     print(f"Column {attri} has <=5 unique values, skipping special processing")
# Out:
# Column Successful transactions in the last month (either $sale or $capture) has unknown unit '6.0'
# Column Purchase amount in the last day has unknown unit '6090.64'
# Column Latest billing address name length has unknown unit '7.0'
# Column Browser fingerprint has unknown unit 'ce4df7656e93054dc90ef25b000cab460ff8dd46'
# Column Latest payment methods single list item has unknown unit '{"payment_type":"$credit_card","payment_gateway":"$ad:-1315462847'
# Column Number of users with the same billing address has unknown unit '6.0'
# Column Estimated email address age has unknown unit '350.15999999999997'
# Column Mobile events in the last month has unknown unit '20.0'
# Column Number of digits in the email username has unknown unit '7.0'
# Column Failed transactions rate in the last day has unknown unit '0.583'
# Column Latest order amount in USD has unknown unit '1173.0'
# Column iOS Device ID has unknown unit 'B6255A9A-399C-4826-84BB-D06FBC0F8C40'
# Column Update accounts in the last day has unknown unit '5.0'
# Column Android System Version has unknown unit '10'
# Column Failed transactions rate in the last month has unknown unit '0.053'
# Column Number of users with the same email address has unknown unit '3.0'
# Column Buyer's account age has unknown unit '0.021666666666666667'
# Column Billing address fingerprint has unknown unit 'ny_11249_brooklyn_541_wythe'
# Column Transactions in the last week has unknown unit '72.0'
# Column Latest phone has unknown unit '15083654151.0'
# Column Median time between page activities has unknown unit '529743.0'
# Column Failed transactions in the last week has unknown unit '1.0'
# Column Phone number has unknown unit '16012605656.0'
# Column Shipping/billing address distance has unknown unit '1493.66'
# Column Ios last location neighborhood ID has unknown unit '33.56,-84.62'
# Column Purchase amount in the last month has unknown unit '6090.64'
# Column IP address has unknown unit '172.56.197.62'
# Column iOS Battery Level has unknown unit '0.05'
# Column Network has unknown unit 'N174.251'
# Column Buyer user account age in hours has unknown unit '8338.102'
# Column Number of users with the same browser + IP Pair has unknown unit '4.0'
# Column Age of first transaction has unknown unit '429.12'
# Column Time to latest buyer's first txn has unknown unit '0.021666666666666667'
# Column Email username keyboard spread has unknown unit '3.361'
# Column Device fingerprint has unknown unit '54vbthhrg91s7dsm907l32t1rg'
# Column Latest account holder name gibberish risk probability has unknown unit '0.061'
# Column Time since previous transaction has unknown unit '0.028666666666666667'
# Column Age of buyer's first transaction has unknown unit '0.0'
# Column Credit card BIN has unknown unit '475833.0'
# Column Number of create contents from an IP to Sift customers in last day. has unknown unit '39.0'
# Column Email gibberish risk probability has unknown unit '0.003'
# Column Transactions in the last hour has unknown unit '10.0'
# Column Account age has unknown unit '0.021666666666666667'
# Column Time since the last buyer's first event has unknown unit '6336.0'
# Column IP/billing distance has unknown unit '1074.42'
# Column Create account phone operator code (OCN) has unknown unit '624H'
# Column Billing name keyboard spread has unknown unit '1.0'
# Column Transaction billing region has unknown unit 'IL'
# Column Purchase amount in the last hour has unknown unit '6090.64'
# Column Account Holder Name has unknown unit 'Manuel'
# Column Travel velocity in the past week (non-ATO) has unknown unit '0.0'
# Column Account phone number normalized has unknown unit '7817967104.0'
# Column Payment method card bin has unknown unit '475833.0'
# Column Purchase amount in USD has unknown unit '1436.35'
# Column Android Device Model has unknown unit 'N159V'
# Column Failed transactions in the last hour has unknown unit '1.0'
# Column Referrer Domain has unknown unit 'blog.flexcar.com'
# Column Number of users with the same phone number has unknown unit '2.0'
# Column Phone number used when user creates an account county population has unknown unit '19015.5'
# Column Account phone number operator code ( ocn ) has unknown unit '624H'
# Column Time since previous event has unknown unit '17.98'
# Column Transactions in the last day has unknown unit '11.0'
# Column Mobile events in the last hour has unknown unit '20.0'
# Column Create account phone county population has unknown unit '26985.0'
# Column Mobile events in the last day has unknown unit '20.0'
# Column Email domain has unknown unit 'protonmail.com'
# Column Local time has unknown unit 'pm'
# Column IP organization has unknown unit 'inc.'
# Column Successful transactions in the last day (either $sale or $capture) has unknown unit '4.0'
# Column Failed transactions per IP in the last day (sift-wide) has unknown unit '19.0'
# Column Number of users with the same cookie has unknown unit '2.0'
# Column Latest name has unknown unit 'Coleman'
# Column Estimated email domain age has unknown unit '1451.52'
# Column Number of create contents from an IP to Sift customers in last 1 hour. has unknown unit '2.0'
# Column Android Mobile Carrier Name has unknown unit 'Mobile'
# Column Device ips count has unknown unit '4.0'
# Column Shipping address fingerprint has unknown unit 'ga_30354_atlanta_2660_fairlane'
# Column Successful transactions in the last hour (either $sale or $capture) has unknown unit '10.0'
# Column Mobile events in the last week has unknown unit '20.0'
# Column Payment method avs result code has unknown unit 'N'
# Column Latest credit card bank has unknown unit 'ASSOCIATION'
# Column iOS System Version has unknown unit '17.5'
# Column iOS Device Model has unknown unit 'iPad6,12'
# Column Number of users with the same device has unknown unit '2.0'
# Column Signup to transaction time has unknown unit '0.021666666666666667'
# Column Latest name keyboard spread has unknown unit '3.757'
# Column Failed transactions per BIN in the last hour (sift-wide) has unknown unit '839.0'
# Column Account phone number county population has unknown unit '19015.5'
# Column Successful transactions in the last week (either $sale or $capture) has unknown unit '6.0'
# Column Normalized email address has unknown unit 'bhb14d@gmail.com'
# Column Timezone offset has unknown unit '-120.0'
# Column Payment fingerprint (card & zip) has unknown unit '5820bf44'
# Column User location has unknown unit '34.05,-118.24'
# Column Billing name length has unknown unit '7.0'
# Column Transaction Account Holder Name has unknown unit 'Manuel'
# Column Digit-Normalized email address has unknown unit 'bigish###@gmail.com'
# Column Billing name fingerprint has unknown unit 'smith'
# Column Email username nearby key rate has unknown unit '0.053'
# Column Create account phone number normalized has unknown unit '5083654151.0'
# Column Purchase amount in the last week has unknown unit '6090.64'
# Column Failed transactions in the last day has unknown unit '1.0'
# Column IP/shipping distance has unknown unit '4181.82'
# Column Referrer URL has unknown unit 'https://blog.flexcar.com/'
# Column timeSinceFirstEvent has unknown unit '49.92'
# Column Number of users with similar email address has unknown unit '3.0'
# Column Email similarity to billing name has unknown unit '0.118'
# Column Changes in payment methods in the last week has unknown unit '1.0'
# Column Transaction_avs_result_code has unknown unit 'U'

# %%
combined_data = data.merge(indicators, left_on='Account Id', right_on = 'Account Id')

# %%
for a in attributes:
    print(a)
    print(combined_data[a].unique())
    print('\n')
# Out:
# Successful transactions in the last month (either $sale or $capture)
# [nan  6.  4.  5. 33.  7. 36. 72. 43. 65.]
#
#
# Purchase amount in the last day
# [     nan  6090.64  4309.05  4184.4   4612.09  6378.2   6472.68  6023.78
#   4577.35  3119.7   4759.23  4431.84  5700.52  4871.63  6133.1   5909.12
#   8167.98  2240.48  3040.87  8006.5   8184.44  2102.76  2408.76  2741.44
#   2115.22  4673.7   5993.92  3544.48  4792.32  4168.78  3415.19  2466.96
#   2209.56  2414.55  5747.77  7709.51  6189.57  4834.45  5955.4   2763.76
#   4176.52  2781.12  5163.24 27666.94  4154.72  6372.8   4698.78  5023.42
#   9055.68  5113.36  5203.28 12315.75  6884.32  6051.46  5289.74  3261.44
#   2219.28  3342.08  3233.34  5874.87  6011.99  4119.84  5945.7   2207.69
#   3623.02  4774.86  3071.16  6075.36  4947.68  5351.38  6841.92  5355.98
#   5738.82  7246.6   7267.96  6084.5   7399.89  6034.2 ]
#
#
# Unique payment fingerprints in the last hour
# [nan  2.  4.]
#
#
# Mobile events in the last minute
# [nan  5.  4.]
#
#
# Latest billing address name length
# [nan  7.  2.  6.  5.  4. 33.]
#
#
# Browser fingerprint
# [None 'ce4df7656e93054dc90ef25b000cab460ff8dd46'
#  'dd188c18df205742d89a6c8a751728423f94c0df'
#  '8c7c25ba3158bbc82bb6a436c2e0744c37a2b74d'
#  '74daa49dfd3f1799102e1db3f93fa07314f4f7a8'
#  'fcecaac9d9b2b8bd04768aed99abb12e3330208f'
#  '3e6721163b91487f96fb92e129800b81e64b0564'
#  '894377fd67943b1e4d2dfa2cccb70804b9ec9169'
#  '23729ca62209e92cda50ee7387678f60e8a455c1'
#  '2da36a060752a48e570cd4441876b87851172edf'
#  '9ac0930ce79c44c9d65fb804cbd4f98648583082'
#  '370d26f8eb2cb770b9a3c9f7cba7410a20874335'
#  '3390a5ac94e43b388d57adecafb3c60962879a03'
#  '6875fc2a2ed88d692cbcaed05c956e603a227541']
#
#
# Seller ID
# [None 'FLEXCAR']
#
#
# Latest name number of words
# [nan  1.]
#
#
# Billing name number of words
# [nan  1.]
#
#
# Latest payment methods single list item
# [None '{"payment_type":"$credit_card","payment_gateway":"$ad:-1315462847'
#  '{"payment_type":"$credit_card","payment_gateway":"$ad:746718190'
#  '{"payment_type":"$credit_card","payment_gateway":"$adyen"}'
#  '{"payment_type":"$credit_card","payment_gateway":"$ad:918824687'
#  '{"payment_type":"$debit_card","payment_gateway":"$ady:-1271104082'
#  '{"payment_type":"$debit_card","payment_gateway":"$ady:-778222739'
#  '{"payment_type":"$debit_card","payment_gateway":"$ady:-1428391110'
#  '{"payment_type":"$debit_card","payment_gateway":"$ady:1745067075'
#  '{"payment_type":"$credit_card","payment_gateway":"$ad:-800841736'
#  '{"payment_type":"$credit_card","payment_gateway":"$ad:2060906757'
#  '{"payment_type":"$debit_card","payment_gateway":"$ady:1370785284'
#  '{"payment_type":"$credit_card","payment_gateway":"$ad
#  9.18333333e-02 1.68720000e+02 2.11800000e+01 1.50240000e+02
#  5.89200000e+02 3.87600000e+02 3.30480000e+02 7.09833333e-01]
#
#
# Update account names in the last week
# [nan  4.  2.]
#
#
# Mobile events in the last month
# [nan 20. 10. 17. 35. 26.  9.]
#
#
# Number of digits in the email username
# [nan  7.  8. 10.  6.  9.  4.  5.]
#
#
# Failed transactions rate in the last day
# [  nan 0.583 0.4   0.333 0.444 0.462 0.455 0.429 0.364 0.481 0.375 0.471
#  0.5   0.467 0.846 0.478]
#
#
# Number of different BINs for transactions in the past week
# [nan  2.  3.  4.]
#
#
# Number of different BINs for transactions in the past day
# [nan  2.  3.]
#
#
# Latest order amount in USD
# [    nan 1173.   1028.   1053.   1119.   1124.34 1123.44  244.   1138.
#  1078.81 1123.   1396.   1287.58 1199.   1137.   1102.88 1938.   1294.
#  1239.88 1294.5  1193.   1269.   1253.    649.   1043.    249.   1163.
#  1034.    229.   1645.54 1183.   1070.64 1058.   1643.   1578.   1223.
#  2053.   2143.  ]
#
#
# Shipping/credit card country match
# [None 'false']
#
#
# iOS Device ID
# [None 'B6255A9A-399C-4826-84BB-D06FBC0F8C40'
#  '2287193D-66ED-407A-9D93-34DFC2580391'
#  '16ED0954-883C-4DD3-97C8-360614CBA9FE'
#  'AD3ACFA7-2EDC-4F39-9DCB-492860402C66'
#  '4388B9E1-14F1-4F25-90AD-5148D3E5887A'
#  '38997CBB-17B1-4F58-BC27-F1F0A81238AE'
#  '41A50AB7-0737-414B-AF21-1D476FFB9BDB'
#  '26B68BAE-3B34-44C4-84C6-F9F54F2D2EF1'
#  'C854E443-78D6-4B85-A884-0C4187778667'
#  '14AC1478-EE6A-4682-9C19-4198886AF42D'
#  'E9FE87DC-704F-49B6-89C1-6C258719B4A9'
#  '5F6BF635-619D-4749-87EA-57ECDAF016DE']
#
#
# Update accounts in the last day
# [nan  5. 11. 13.  8.  6.  7. 27.  4. 12.  9. 18. 14. 10.]
#
#
# Android System Version
# [None 'Android 10' 'Android 12' 'Android 8.1.0' 'Android 15' 'Android 13'
#  'Android 9']
#
#
# Billing name number of digits
# [nan 16.]
#
#
# Failed transactions rate in the last month
# [  nan 0.053 0.583 0.769 0.6   0.5   0.429 0.667 0.444 0.647 0.471 0.481
#  0.714 0.455 0.462 0.571 0.609 0.478 0.56 ]
#
#
# Unique Billing Names in Orders (Day)
# [nan  2.]
#
#
# Failed transactions rate in the last minute
# [  nan 0.5   0.333 0.4  ]
#
#
# Number of users with the same email address
# [nan  3.  2.  4.  9. 15.  6. 10.]
#
#
# Country
# [None 'Republic of Korea' 'Italy' 'India']
#
#
# Transaction_cvv_result_code
# [None 'N' 'P']
#
#
# Buyer's account age
# [           nan 2.16666667e-02 2.10000000e-02 6.46128000e+03
#  7.12152000e+03 6.37968000e+03 6.30624000e+03 6.46944000e+03
#  7.21536000e+03 1.95000000e-02 6.67512000e+03 2.25000000e-02
#  1.36666667e-02 6.86040000e+03 2.33333333e-02 7.38456000e+03
#  'ga_30349_atlanta_7293_simon' 'nc_28202_charlotte_620_church'
#  'ma_02120_boston_10_hammond' 'ga_30308_atlanta_116_ponce_de_leon'
#  'ma_01778_wayland_492_boston_post' 'ga_30303_atlanta_210_pryor'
#  'nc_28262_charlotte_11023_tavernay'
#  'va_24060_blacksburg_10600_blue_ridge'
#  'ga_30519_buford_3256_mill_springs_cir'
#  'ri_02863_central_falls_41_cleveland'
#  'tn_37211_nashville_100_antioch_pike'
#  'ga_30078_snellville_2217_foley_park' 'ga_30038_lithonia_3296_corktree'
#  'ga_30341_atlanta_3224_mercer_university'
#  'ga_30314_atlanta_1733_detroit_ct' 'ga_30339_atlanta_2735_paces_ferry'
#  'ny_11550_hempstead_130_rhodes' 'ok_74361_pryor_96_465'
#  'ga_30276_senoia_151_drayton_farm' 'ga_30157_dallas_225_summer_creek'
#  'ny_11219_brooklyn_5614_15th_2d' 'ny_11205_brooklyn_35_skillman'
#  'ga_30344_atlanta_3340_penny_f' 'ma_01520_holden_1300_newbury'
#  'ma_02747_north_dartmouth_285_old_westport'
#  'ga_30062_marietta_2085_roswell']
#
#
# Payment method payment gateway
# [None '$stripe']
#
#
# Transactions in the last week
# [nan 72. 24. 21. 19. 18. 16. 65. 17.]
#
#
# Latest phone
# [           nan 1.50836542e+10 1.60181289e+10 1.51869860e+10
#  1.47064799e+10 1.67886289e+10 1.47027251e+10 1.92940949e+10
#  1.61789969e+10 1.47088469e+10 1.40457331e+10 1.86032897e+10
#  1.41339166e+10 1.67858076e+10 1.95925738e+10 1.47057354e+10
#  1.98041865e+10 1.61775980e+10]
#
#
# Median time between page activities
# [5.297430e+05          nan 3.092710e+05 6.527860e+05 7.548430e+05
#  5.942110e+05 1.038598e+06 5.515440e+05 7.005250e+05 6.745110e+05
#  1.419070e+06 1.449435e+06 8.803890e+05 5.940880e+05 6.265280e+05
#  6.751250e+05 6.862690e+05 3.004180e+05 3.177600e+05 5.653430e+05
#  9.038850e+05 7.109670e+05 5.787880e+05 1.650000e+02 6.065250e+05
#  1.057215e+06 1.619945e+06 5.662290e+05 7.964860e+05 7.437180e+05
#  1.001817e+06 5.672090e+05 1.076598e+06 7.563130e+05 9.433920e+05
#  6.730220e+05 3.990670e+05 5.834260e+05 9.526470e+05 6.220510e+05
#  6.878920e+05 5.248020e+05 1.719849e+06 6.361460e+05 1.408961e+06
#  1.376137e+06 5.391450e+05 7.746100e+05 1.482749e+06 1.221689e+06]
#
#
# Failed transactions in the last week
# [nan  1.  3.  2.  7.  5.  6.  4.  8. 10.  9.]
#
#
# Phone number
# [           nan 1.60126057e+10 1.98031327e+10 1.41297388e+10
#  1.40469080e+10 1.50836542e+10 1.60181289e+10 1.51869860e+10
#  1.40479813e+10 1.70420603e+10 1.47027251e+10 1.47825102e+10
#  1.61763795e+10 1.92940949e+10 1.67842185e+10 1.67843141e+10
#  1.61591870e+10 1.31927069e+10 1.98021602e+10 1.61789969e+10
#  1.85754462e+10 1.40471645e+10 1.20351786e+10 1.61736707e+10
#  1.85728760e+10 1.40458125e+10 1.47088469e+10 1.40457331e+10
#  1.61771062e+10 1.77077072e+10 1.30374699e+10 1.86032897e+10
#  1.50888908e+10 1.97873576e+10 1.61730443e+10 1.34776931e+10
#  1.72479727e+10 1.32397836e+10 1.41320418e+10 1.47027836e+10
#  1.47097955e+10 1.61795343e+10 1.40468306e+10 1.41335686e+10
#  1.78654797e+10 1.85727629e+10 1.51672135e+10 1.40484019e+10
#  1.30254058e+10 1.33921396e+10 1.68234015e+10 1.41339166e+10
#  1.67858076e+10 1.62930931e+10 1.40486063e+10 1.40450363e+10
#  1.95925738e+10 1.77398345e+10 1.91490698e+10 1.21573041e+10
#  1.50466908e+10 1.61567893e+10 1.85745241e+10 1.47058344e+10
#  1.78186634e+10 1.40493461e+10 1.71651765e+10 1.78746382e+10
#  1.84345588e+10 1.41489726e+10 1.98041865e+10 1.94325778e+10
#  1.61775980e+10 1.67883680e+10 1.66177265e+10 1.31323608e+10
#  1.50852758e+10 1.92947134e+10]
#
#
# Failed transactions rate in the last week
# [  nan 0.053 0.583 0.7   0.5   0.027]
#
#
# Number of users with the same Payment fingerprint (card & zip)
# [nan  3.  2.  4.]
#
#
# Latest credit card country
# [None 'China']
#
#
# IP/shipping country match
# [None 'false']
#
#
# Non-transaction API event without page view or mobile event
# [None 'true']
#
#
# Account phone number country code
# [None 'Italy' 'India' 'Portugal']
#
#
# Unique Order Billing Addresses (Day)
# [nan  2.]
#
#
# Shipping/billing address distance
# [    nan 1493.66 4071.73  307.2   831.21  161.49 1407.82 3386.71 2787.21
#  1088.89 4016.52 3674.04 3148.8   150.5  1176.38 3091.97 1185.85 4085.17
#  4341.43 4306.66 1959.25  995.92 1111.29 3994.02 3123.59  418.2  3499.59
#    35.58 4329.76  175.27  494.37 1512.4  3092.79 2591.43 3676.57 4184.99
#   761.3  3396.29 2181.16  296.91  219.61 3146.11   58.94 2581.32 3058.12
#  1227.97 3717.22 1451.45 1509.61 4190.9  3987.4  2520.5  2517.07 3425.86
#   683.04 1362.44 3644.78 4333.6   893.86 1960.93 4281.69 3197.17 1938.08]
#
#
# Latest billing address name casing
# [None 'mixed' 'upper']
#
#
# Ios last location neighborhood ID
# [None '33.56,-84.62' '33.94,-84.07' '41.76,-71.96' '35.21,-80.83'
#  '42.20,-71.08' '41.80,-69.96' '33.71,-84.15' '-34.62,-58.38'
#  '33.84,-84.38' '33.75,-84.24' '33.87,-84.26' '33.56,-84.30'
#  '42.40,-71.15' '33.74,-84.31' '36.13,-80.30' '33.55,-84.26'
#  '33.77,-84.38' '42.34,-71.11' '41.70,-71.53' '33.69,-84.26'
#  '40.75,-74.21' '33.78,-84.09' '41.88,-71.38' '33.37,-84.32'
#  '33.65,-84.51' '40.87,-73.92' '40.00,-83.00' '39.20,-76.69'
#  '36.16,-80.28' '33.68,-84.42' '33.76,-84.19' '41.26,-75.89'
#  '41.86,-71.35' '36.23,-86.75' '42.32,-71.18' '34.07,-84.30'
#  'morganashley685@gmail.com' 'delisedavis1985@gmail.com'
#  'taniyahdayshall4@gmail.com' 'vep81909@gmail.com'
#  'hartwaytennille@yahoo.com' 'wallison333@gmail.com' 'jeancorrea@msn.com'
#  'shayhype@gmail.com' 'val@vmodonnell.com'
#  'monicawilliamsleonard@gmail.com' 'kaliahiadavis@gmail.com'
#  'grahamsteve71@gmail.com' 'rerehoward482@gmail.com'
#  'ashleys1541@yahoo.com' 'theodoreblackwell2025@gmail.com'
#  'fgibbons@outlook.com' 'williamsjordan823@gmail.com'
#  'jmint404@icloud.com' 'tyrese0699@gmail.com'
#  'lorenzojrbrown1010@gmail.com' 'lobobetinho@gmail.com'
#  'alannapina00@gmail.com' 'kaylahbreanne@gmail.com' 'kefamusic@icloud.com'
#  'joshuasaltercs@gmail.com' 'jsklba88@icloud.com' 'juslisn1281@gmail.com']
#
#
# Latest shipping address name number of words
# [nan  1.]
#
#
# Timezone offset
# [  nan -120.  420. -480. -540.  -60. -360. -300.    0.  480. -180.  180.
#   540. -420. -240.]
#
#
# Latest amount
# [     nan 2.44e+08 2.59e+08 2.64e+08 2.49e+08 2.29e+08]
#
#
# Payment fingerprint (card & zip)
# [None '5820bf44' '10cc093c' 4.154e+60 '74be5d65' '220b8204' '05bee05f']
#
#
# Billing/credit card country match
# [None 'false']
#
#
# User location
# [None '34.05,-118.24' '33.74,-84.10' '34.00,-83.35' '33.92,-84.68'
#  '33.72,-84.34' '33.76,-84.65' '33.69,-84.15' '33.76,-84.42']
#
#
# Latest shipping address name keyboard spread
# [ nan 3.85]
#
#
# Billing name length
# [nan  7.  5.  6. 44.  2.  4.  3. 36. 33. 37.]
#
#
# Transaction Account Holder Name
# [None 'Brianna Manuel' 'Sao Lim' 'Michael Smith' 'Alexander Stewart'
#  'Tiffany Williams' 'Mark Lee' 'James Davis']
#
#
# Number of users with the same billing name
# [nan  2.  5.  3. 12.  4.]
#
#
# Digit-Normalized email address
# [None 'bigish###@gmail.com' 'berl####@gmail.com' 'chmg####@gmail.com'
#  'jacquelynw###@gmail.com' 'yujuewang###@gmail.com' 'nmore#@gatech.edu'
#  'bhb##d@gmail.com' 'certified####@gmail.com' 'deia####@gmail.com'
#  'xpixley##@gmail.com' 'jonathanbrown###@outlook.com'
#  'christopherdeon##@gmail.com' 'cmk##@att.net' 'ann######@gmail.com'
#  'a##########@gmail.com' 'jesses####@gmail.com' 'nycboonfarms@gmail.com'
#  'fishel###@gmail.com' 'taneishacarr##@gmail.com' 'feder#####@gmail.com'
#  'allenladies@yahoo.com' 'kayyespinal@gmail.com' 'corielles##@gmail.com'
#  'jjwhite###@gmail.com' 'bj########@yahoo.com'
#  'laurarodriguez###@outlook.com' 'ginawilliams####@gmail.com'
#  'ericcharm###@proton.me' 'alturner##@gmail.com' 'lyric####@gmail.com'
#  'twane##@gmail.com' 'pediaiah##@gmail.com' 'petersonjoseph###@gmail.com'
#  'andreavizzarro@gmail.com' 'karthikkv##@gmail.com'
#  'willjlawrence#@gmail.com' 'selah######@gmail.com'
#  'shell#######@gmail.com' 'brianmsellars@gmail.com' 'ecar##@icloud.com'
#  'daven###@gmail.com' 'justinbanks####@gmail.com' 'jdominick###@gmail.com'
#  'joeharrison#####@gmail.com' 'ellenwelch####@gmail.com'
#  'tyfrom###@gmail.com' 'aprilkatrinajohnson@gmail.com'
#  'rachelbeth###@gmail.com' 'timjarrett##@gmail.com'
#  'candacekissi@gmail.com' 'shmielb####@gmail.com' 'alonzo####@yahoo.com'
#  'jamestapp###@gmail.com' 'jmoore######@gmail.com' 'khca###@gmail.com'
#  'hersheygelb@gmail.com' 'chanelnicole@myyahoo.com'
#  'kingkay####@gmail.com' 'smrterthnavrge@gmail.com'
#  'queengetmoneystacks@gmail.com' 'jaylon##@gmail.com' 'blimy###@gmail.com'
#  'jnal####@gmail.com' 'johndeere##@icloud.com' '#########@qq.com'
#  'seanerika#@gmail.com' 'dombriesmith##@gmail.com'
#  'ericsmith######@gmail.com' 'taylorwatts####@gmail.com'
#  'jameelajenkins@gmail.com' 'fastlane####@gmail.com'
#  'mikeraymond####@gmail.com' 'diamondhall####@gmail.com'
#  'taniyahdayshall#@gmail.com' 'nylashacromwell@gmail.com'
#  'shayparks####@gmail.com' 'tresh####@gmail.com' '#######@gmail.com'
#  'weny#####@gmail.com' 'burrpk@gmail.com' 'kimszwicke@gmail.com'
#  'cargoindigo@icloud.com' 'mc####@icloud.com' 'rerehoward###@gmail.com'
#  'delisedavis####@gmail.com' 'theodoreblackwell####@gmail.com'
#  'donnasmith###@yahoo.com' 'sylessesutton##@gmail.com']
#
#
# Unique Billing Names (past month)
# [nan  2.  3.  4.  7.]
#
#
# Unique Shipping Add in Orders (Month)
# [nan  2.]
#
#
# Billing name fingerprint
# [None 'cody smith' 'robert harris' 'micah blossomgame' 'sao lim'
#  'stephanie baker' 'jeremy davis' 'deyana burnett' 'ashley johnson'
#  'emily white' 'visa' 'rita martin' 'michael williams' 'alexander stewart'
#  'eric charm' 'jacob smith' 'theresa harvey' 'juan rivera'
#  'dominick caraballo' 'crystal brown' 'jennifer colon' 'joshua matthews'
#  'isaac estrada' 'courtney simmons' 'pierre downs' 'abraham lowinger'
#  'jacob holliday' 'brian thomas' 'tiffany williams' 'wei zhang'
#  'april wilson' 'moshe hershkowitz' 'jocelyn williams' 'joseph smith'
#  'jalen smith' 'jonathan johnson' 'mark lee' 'james davis' 'alex ashley'
#  'timothy jacob' 'jason jones' 'anthony oliver' 'brittany'
#  'matthew donovan' 'derrick richardson']
#
#
# Latest shipping address address 1
# [None '2660 Fairlane Dr SE' '782 Peachtree St Ne']
#
#
# Email username nearby key rate
# [  nan 0.053 0.059 0.056 0.05  0.042 1.    0.   ]
#
#
# Create account phone number normalized
# [           nan 5.08365415e+09 6.01812894e+09 5.18698599e+09
#  7.04206032e+09 6.78862890e+09 4.70272509e+09 9.78735393e+09
#  9.29409485e+09 6.17899692e+09 4.70884695e+09 4.04573313e+09
#  4.04451101e+09 8.60328973e+09 7.86547973e+09 4.13391658e+09
#  6.78580763e+09 9.59257379e+09 7.81866337e+09 9.80418651e+09
#  6.17759798e+09]
#
#
# Payment method card last 4
# [nan  5.]
#
#
# Transaction without page view
# [None 'true']
#
#
# Purchase amount in the last week
# [     nan  6090.64  6719.89  4309.05  4689.56  4612.09  6378.2   6472.68
#   6023.78  6530.45  2325.78  4759.23  4431.84  5700.52  4871.63  8167.98
#   2240.48  3040.87  8006.5   3401.86  2187.83  8184.44  2348.42  3179.1
#   2102.76  2408.76  2741.44  2115.22  4673.7   5993.92  7492.4   4792.32
#   4168.78  4391.9   8422.07  2466.96  2209.56  2414.55  5747.77  6189.57
#   4834.45  6516.7   5955.4   6314.82  4176.52  5109.71  5163.24 27666.94
#   5221.44  4154.72  6372.8  10602.56  5113.36  5203.28  8124.6   4190.26
#   6884.32  5061.64  6051.46  3261.44  2855.36  2219.28  3342.08  3233.34
#   5874.87  6011.99  4119.84  5945.7   8244.1   4691.54  2207.69  2553.75
#   6136.42  3623.02  2063.93  4480.96  4774.86  3071.16  6075.36  4947.68
#   5351.38  5612.7   6841.92  5355.98  5738.82  8695.92  5600.6   4301.59
#   4209.86  7267.96  4505.33  5774.5   4839.3   6084.5   7399.89  6034.2 ]
#
#
# Latest name number of digits
# [nan  3.]
#
#
# Failed transactions in the last day
# [nan  1.  3.  2.  7.  5.  6.  4.]
#
#
# Transaction without page view or mobile event
# [None 'true']
#
#
# Number of users with the same shipping name
# [nan  7.  2.  3. 13.]
#
#
# IP/shipping distance
# [         nan 4.181820e+03 3.801700e+02 2.958600e+02 4.073570e+03
#  3.897210e+03 4.032200e+02 3.109960e+03 4.238600e+02 3.650770e+03
#  1.282062e+04 2.860350e+03 2.751000e+03 1.447470e+04 3.415090e+03
#  1.272771e+04 2.337940e+03 4.000000e-02 4.905800e+02 2.829250e+03
#  3.148950e+03 3.056400e+02 5.563020e+03 7.744990e+03 1.987810e+03
#  2.984300e+02 1.292130e+03 3.233000e+02 3.383640e+03 3.112480e+03
#  1.235514e+04 7.036870e+03 3.379610e+03 2.721670e+03 2.939300e+02
#  3.129100e+03 2.832700e+02 1.160026e+04 6.563810e+03 4.280930e+03
#  3.118140e+03 1.319635e+04 3.138290e+03 1.884900e+02 4.148290e+03
#  3.422030e+03]
#
#
# Billing/shipping name similarity
# [  nan 0.061]
#
#
# Referrer URL
# [None 'https://blog.flexcar.com/' 'https://support.flexcar.com/'
#  'https://www.bing.com/' 'https://flexcar.worthepenny.com/coupon/'
#  'https://flexcar.knoji.com/' 'https://www.google.com/'
#  'https://www.reddit.com/']
#
#
# Browser+IP fingerprint
# [None '7af1a4d8f3a173c3c2f05b1a2e53f20d2693ed73']
#
#
# timeSinceFirstEvent
# [           nan 4.99200000e+01 4.80000000e+01 9.01833333e-01
#  6.48000000e+01 3.89280000e+02 8.13600000e+02 9.38400000e+01
#  7.10400000e+01 4.73520000e+02 9.48000000e-01 4.41840000e+02
#  7.21536000e+03 6.81600000e+01 6.67512000e+03 1.66666667e-04
#  8.30400000e+01 1.53624000e+03 2.60112000e+03 6.14400000e+01
#  1.59432000e+03 2.43816000e+03 1.69800000e+03 1.61688000e+03
#  3.86160000e+02 2.23728000e+03 1.92048000e+03 4.43333333e-02
#  8.68800000e+01 1.74552000e+03 1.90000000e-02 2.01666667e-02
#  1.58333333e-02 1.91666667e-02 3.90000000e-02]
#
#
# Number of users with similar email address
# [nan  3.  2.  5.  4. 12.  9.  7. 14. 15. 21.  6. 11. 10. 20. 18.  8.]
#
#
# Number of unique payment methods in the past 7 days
# [nan  3.  4.  2.  5.]
#
#
# Android Device ID
# [None '7e5610ec57804632' 'd85b5e45bace987c' '71c9e1c4ea18a416'
#  '05892bf70761ce42']
#
#
# Changes in payment methods in the last hour
# [nan  2.  3.  4.]
#
#
# Latest shipping address city
# [None 'Atlanta']
#
#
# Unique shipping addresses
# [nan  2.]
#
#
# Email similarity to billing name
# [0.118   nan 0.    0.059 0.083 0.1   0.071 0.062 0.091 0.077 0.053 0.111
#  0.105 0.056 0.067 0.143 0.087 0.048 0.125]
#
#
# Number of unique payment methods in the past week (Update Accounts).
# [nan  2.  3.  4.]
#
#
# Changes in payment methods in the last week
# [nan  1.  2.  5.  3.  4.  8. 12.]
#
#
# Payment type
# [None 'SUBSCRIPTION' 'ORDER']
#
#
# Unique billing BINs (past day)
# [nan  2.  3.]
#
#
# Transaction billing zip
# [   nan 30054. 30311.]
#
#
# Transaction billing city
# [None 'Stonecrest']
#
#
# Transaction_avs_result_code
# [None 'U' 'E' 'N' 'S' 'R' 'X' 'O']

# %%
combined_data[['Abuse Score_y', 'Payment Failure']].groupby('Payment Failure').median()
# Out:
#                  Abuse Score_y
# Payment Failure
# 0                         0.04
# 1                         0.05

# %%
numeric_cols_df = combined_data.select_dtypes(include='number')
columns = list(set(numeric_cols_df.columns).intersection(set(attributes))) + ['Abuse Score_x']
for num in numeric_cols_df.columns:
    combined_data[num] = combined_data[num].fillna(0)

# %%
import pandas as pd
from scipy.stats import ttest_ind, mannwhitneyu
import math

def unpaired_test_per_attribute(df, group_col, attributes, test='t'):
    """
    Perform unpaired statistical test on multiple attributes for two groups,
    and include group means in the result.
    
    Parameters:
    - df: pandas DataFrame containing data
    - group_col: name of the column containing group labels
    - attributes: list of attribute column names to test
    - test: 't' for Welch's t-test, 'mw' for Mann-Whitney U test
    
    Returns:
    - pandas DataFrame with columns:
      attribute, group1_mean, group2_mean, test_statistic, p_value
    """
    groups = df[group_col].dropna().unique()
    if len(groups) != 2:
        raise ValueError(f"Expected exactly 2 groups in '{group_col}', found {len(groups)}: {groups}")
    
    results = []
    for attr in attributes:
        group1_data = df.loc[df[group_col] == groups[0], attr].dropna()
        group2_data = df.loc[df[group_col] == groups[1], attr].dropna()

        # Calculate means, use NaN if no data
        group1_mean = group1_data.mean() if len(group1_data) > 0 else math.nan
        group2_mean = group2_data.mean() if len(group2_data) > 0 else math.nan

        if len(group1_data) == 0 or len(group2_data) == 0:
            stat, p = math.nan, math.nan
        else:
            if test == 't':
                stat, p = ttest_ind(group1_data, group2_data, equal_var=False)
            elif test == 'mw':
                stat, p = mannwhitneyu(group1_data, group2_data, alternative='two-sided')
            else:
                raise ValueError("test must be 't' or 'mw'")
        
        results.append({
            'attribute': attr,
            f'{groups[0]}_mean': group1_mean,
            f'{groups[1]}_mean': group2_mean,
            'test_statistic': stat,
            'p_value': p
        })

    return pd.DataFrame(results)

# def unpaired_test_per_attribute(df, group_col, attributes, test='t'):
#     """
#     Perform unpaired statistical test on multiple attributes for two groups.
    
#     Parameters:
#     - df: pandas DataFrame containing data
#     - group_col: name of the column containing group labels
#     - attributes: list of attribute column names to test
#     - test: 't' for t-test (Welch), 'mw' for Mann-Whitney U test
    
#     Returns:
#     - pandas DataFrame with columns: attribute, test_statistic, p_value
#     """
#     # Extract group labels
#     groups = df[group_col].dropna().unique()
#     if len(groups) != 2:
#         raise ValueError(f"Expected exactly 2 groups in '{group_col}', found {len(groups)}: {groups}")
    
#     results = []
#     for attr in attributes:
#         # Drop NaNs for this attribute & group, to avoid errors in tests
#         group1_data = df.loc[df[group_col] == groups[0], attr].dropna()
#         group2_data = df.loc[df[group_col] == groups[1], attr].dropna()

#         if len(group1_data) == 0 or len(group2_data) == 0:
#             # Not enough data to test
#             stat, p = math.nan, math.nan
#         else:
#             if test == 't':
#                 stat, p = ttest_ind(group1_data, group2_data, equal_var=False)
#             elif test == 'mw':
#                 stat, p = mannwhitneyu(group1_data, group2_data, alternative='two-sided')
#             else:
#                 raise ValueError("test must be 't' or 'mw'")
        
#         results.append({'attribute': attr, 'test_statistic': stat, 'p_value': p})

#     return pd.DataFrame(results)

# %%
test_results = unpaired_test_per_attribute(combined_data, 'Payment Failure', columns, test='t')

# %%
top_attributes = test_results[test_results['p_value']<0.05]
top_attributes
# Out:
#                                              attribute      0_mean     1_mean  \
# 1                      Purchase amount in the last day   25.355851  82.430156
# 2                     Mobile events in the last minute    0.036150   0.010693
# 7        Number of users with the same billing address    0.159431   0.104255
# 8                          Estimated email address age  115.307926  76.601890
# 9                Update account names in the last week    0.001390   0.000000
# ..                                                 ...         ...        ...
# 165         Number of users with similar email address    0.060405   0.323235
# 166  Number of unique payment methods in the past 7...    0.018693   0.004455
# 169                   Email similarity to billing name    0.002846   0.002037
# 170  Number of unique payment methods in the past w...    0.035455   0.069280
# 171        Changes in payment methods in the last week    0.036845   0.091334
#
#      test_statistic       p_value
# 1         -4.681177  2.924952e-06
# 2          5.060756  4.227087e-07
# 7          4.825870  1.409521e-06
# 8          3.974512  7.101951e-05
# 9          2.183138  2.904354e-02
# ..              ...           ...
# 165      -10.528846  1.105425e-25
# 166        5.877310  4.248474e-09
# 169        3.363948  7.716437e-04
# 170       -5.392407  7.205272e-08
# 171       -8.562194  1.412021e-17
#
# [89 rows x 5 columns]

# %%
top_attri_names = top_attributes['attribute'].to_list()
combined_data[top_attri_names+['Payment Failure']].groupby('Payment Failure').mean().T
# Out:
# Payment Failure                                              0          1
# Purchase amount in the last day                      25.355851  82.430156
# Mobile events in the last minute                      0.036150   0.010693
# Number of users with the same billing address         0.159431   0.104255
# Estimated email address age                         115.307926  76.601890
# Update account names in the last week                 0.001390   0.000000
# ...                                                        ...        ...
# Number of users with similar email address            0.060405   0.323235
# Number of unique payment methods in the past 7 ...    0.018693   0.004455
# Email similarity to billing name                      0.002846   0.002037
# Number of unique payment methods in the past we...    0.035455   0.069280
# Changes in payment methods in the last week           0.036845   0.091334
#
# [89 rows x 2 columns]

# %%
test_results[test_results['p_value']<0.05].to_csv('../data/sift_ttest_results.csv',index=False)

# %%
#. json data
"Latest payment methods single list item"

# %%
import pandas as pd
from scipy.stats import chi2_contingency

def chi_square_per_feature(df, group_col, features):
    results = []
    for feature in features:
        # Contingency table of feature vs group
        contingency = pd.crosstab(df[feature], df[group_col])

        # Skip feature if contingency table invalid (e.g. all one category)
        if contingency.shape[0] < 2 or contingency.shape[1] < 2:
            continue

        chi2, p, dof, expected = chi2_contingency(contingency)

        results.append({
            "feature": feature,
            "chi2_statistic": chi2,
            "p_value": p,
            "degrees_of_freedom": dof
        })

    results_df = pd.DataFrame(results)
    results_df = results_df.sort_values("p_value").reset_index(drop=True)
    return results_df



def fill_nans_in_boolean_columns(df):
    for col in df.columns:
        # select column if dtype is boolean or contains only True/False/NaN
        # We treat columns whose unique non-null values are subset of {True, False}
        unique_vals = set(df[col].dropna().unique())

        if unique_vals.issubset({True, 'false'}):
            # Check if only True or only False present (plus NaNs)
            if unique_vals == {'true'}:  
                # only True + NaN, fill NaN with False or leave? You want to fill NaN with True if only false, opposite if only true:
                # The user said: if only false + NaN, fill NaN with True; if only true + NaN, fill NaN with False.
                # So here unique_vals == {True} means only True + NaN → fill NaN with False
                df[col] = df[col].fillna('false')

            elif unique_vals == {'false'}:  
                # only False + NaN → fill NaN with True
                df[col] = df[col].fillna('true')

            # if both True and False present, do nothing

    return df

# %%
cat_cols_df = combined_data.select_dtypes(include='object')
meaningful_cat = []
for col in cat_cols_df.columns:
    if 1 < len(cat_cols_df[col].unique())<= 5: # if the number of unique value in cat data is greater then 1 and no less than 5
        meaningful_cat.append(col)

# filter the meaningful cat data
remove_list = ['Decision', 'Market ID', 'Browser/OS V2', 'Browser/OS V2']
filtered_list = [x for x in meaningful_cat if x not in remove_list]


combined_data = fill_nans_in_boolean_columns(combined_data)

# meaningful_cat 
result_df = chi_square_per_feature(combined_data, "Payment Failure", meaningful_cat)

# %%
meaningful_cat
# Out:
# ['Decision',
#  'Workflow Name',
#  'Seller ID',
#  'Shipping/credit card country match',
#  'Country',
#  'Transaction_cvv_result_code',
#  'Payment method payment gateway',
#  'Latest credit card country',
#  'IP/shipping country match',
#  'Non-transaction API event without page view or mobile event',
#  'Account phone number country code',
#  'Latest billing address name casing',
#  'Shipping name casing',
#  'Latest billing address region',
#  'Phone number used when user creates an account operator code ( ocn )',
#  'Non-transaction API event without page view',
#  'Latest billing address name',
#  'IP is Proxy, VPN, or hosting service',
#  'Latest billing address address 1',
#  'Latest billing address city',
#  'Disposable email domain',
#  'Browser/OS V2',
#  'Latest name casing',
#  'IP/billing country codes pair',
#  'Latest shipping address name casing',
#  'Billing address has lengthy unit number',
#  'IP/credit card country match',
#  'iOS Mobile Device Name',
#  'IP/shipping country codes pair',
#  'Android last location neighborhood ID',
#  'Billing address has forwarding terms',
#  'Market ID',
#  'Latest shipping address name',
#  'Transaction_payment_gateway',
#  'Payment method cvv result code',
#  'Phone number used when user creates an account line and operator type',
#  'Latest shipping address region',
#  'Billing first and last names match',
#  'Billing name casing',
#  'Transaction_verification_status',
#  'Create account phone number country code',
#  'Latest promotion ID',
#  'Shipping name fingerprint',
#  'Email username casing',
#  'IP/billing country match',
#  'Payment Type',
#  'Cookie fingerprint',
#  'Account phone number line and operator type',
#  'Latest shipping method',
#  'Android Mobile Carrier Country',
#  'Transaction_payment_type',
#  'Create account phone line and operator type',
#  "Host providing this user's email service",
#  'Billing/credit card country match',
#  'Latest shipping address address 1',
#  'Transaction without page view',
#  'Transaction without page view or mobile event',
#  'Browser+IP fingerprint',
#  'Android Device ID',
#  'Latest shipping address city',
#  'Payment type',
#  'Transaction billing city']

# %%
# result_df[result_df['p_value'] < 0.05]
result_df
# Out:
#                                               feature  chi2_statistic  \
# 0                                           Market ID       32.238966
# 1                                            Decision       34.198528
# 2                                       Browser/OS V2       18.000000
# 3                      Android Mobile Carrier Country        8.000000
# 4                       Latest billing address region        8.800000
# 5                                 Billing name casing        4.503810
# 6                                             Country        5.958333
# 7                                   Android Device ID        7.200000
# 8                    Latest billing address address 1        7.000000
# 9                                  Cookie fingerprint        3.733333
# 10                                      Workflow Name        1.884987
# 11  Phone number used when user creates an account...        5.000000
# 12        Account phone number line and operator type        3.463692
# 13        Create account phone line and operator type        3.206407
# 14           Host providing this user's email service        3.080000
# 15              Android last location neighborhood ID        4.000000
# 16                                Latest promotion ID        1.000000
# 17                 Latest billing address name casing        1.000000
# 18                                       Payment type        0.963174
# 19                     Payment method cvv result code        0.286458
# 20                        Transaction_cvv_result_code        0.286458
# 21           Create account phone number country code        1.196581
# 22                 Shipping/credit card country match        0.086088
# 23                      IP/billing country codes pair        1.058824
# 24                                 Latest name casing        0.018546
# 25                     Latest shipping address region        0.000000
#
#          p_value  degrees_of_freedom
# 0   1.363291e-08                   1
# 1   3.748728e-08                   2
# 2   4.398497e-04                   3
# 3   1.831564e-02                   2
# 4   3.207164e-02                   3
# 5   3.381942e-02                   1
# 6   5.083518e-02                   2
# 7   6.578905e-02                   3
# 8   7.189777e-02                   3
# 9   1.546383e-01                   2
# 10  1.697684e-01                   1
# 11  1.717971e-01                   3
# 12  1.769575e-01                   2
# 13  2.012508e-01                   2
# 14  2.143811e-01                   2
# 15  2.614641e-01                   3
# 16  3.173105e-01                   1
# 17  3.173105e-01                   1
# 18  3.263886e-01                   1
# 19  5.924991e-01                   1
# 20  5.924991e-01                   1
# 21  7.538244e-01                   3
# 22  7.692111e-01                   1
# 23  7.870224e-01                   3
# 24  8.916754e-01                   1
# 25  1.000000e+00                   1

# %%
for col in meaningful_cat:
    print(pd.crosstab(combined_data[col], combined_data['Payment Failure']))
    print('\n')
# Out:
# Payment Failure      0     1
# Decision
# APPROVE          10735  3548
# NONE                28    10
# REVIEW            2183   931
#
#
# Payment Failure                0     1
# Workflow Name
# Prod_Payments_Risk         12286  4284
# Prod_Payments_Risk_202508    660   205
#
#
# Payment Failure  0  1
# Seller ID
# FLEXCAR          4  4
#
#
# Payment Failure                         0     1
# Shipping/credit card country match
# True                                12918  4481
# false                                  28     8
#
#
# Payment Failure     0  1
# Country
# India              10  0
# Italy               1  1
# Republic of Korea   1  0
#
#
# Payment Failure              0  1
# Transaction_cvv_result_code
# N                            8  2
# P                            0  1
#
#
# Payment Failure                   0   1
# Payment method payment gateway
# $stripe                         177  41
#
#
# Payment Failure              0   1
# Latest credit card country
# China                       23  12
#
#
# Payment Failure                                       0   1
# Non-transaction API event without page view or ...
# true                                                203  58
#
#
# Payment Failure                    0
# Account phone number country code
# India                              1
# Italy                              4
# Portugal                           1
#
#
# Payment Failure                     0  1
# Latest billing address name casing
# mixed                               2  0
# upper                               0  2
#
#
# Payment Failure        0  1
# Shipping name casing
# lower                 78  8
#
#
# Payment Failure                0  1
# Latest billing address region
# AK                             3  0
# Georgia                        2  0
# PA                             1  4
# TX                             0  2
#
#
# Payment Failure                                     0  1
# Phone number used when user creates an account ...
# 6003.0                                              0  1
# 072F                                                0  1
# 637C                                                2  0
# 638E                                                0  1
#
#
# Payment Failure                                0   1
# Non-transaction API event without page view
# true                                         353  74
#
#
# Payment Failure              0
# Latest billing address name
# Chang Liu                    3
#
#
# Payment Failure                         0   1
# IP is Proxy, VPN, or hosting service
# true                                  178  22
#
#
# Payment Failure                   0  1
# Latest billing address address 1
# 201 Moury Ave SW                  2  0
# 27 Lyon St                        2  0
# 303 Mlk Sr Heritage Trl           1  0
# 691 East 4th Street               0  2
#
#
# Payment Failure              0
# Latest billing address city
# Stonecrest                   3
#
#
# Payment Failure          0
# Disposable email domain
# true                     1
#
#
# Payment Failure              0  1
# Browser/OS V2
# Android 12-AppleWebKit 537   0  1
# Android 12-Chrome 95         0  4
# Mac OS 10.15-Chrome 96       1  0
# Windows NT ??-Chrome 110    12  0
#
#
# Payment Failure       0   1
# Latest name casing
# lower               443  14
# mixed                12   1
#
#
# Payment Failure                0  1
# IP/billing country codes pair
# AT_US                          2  0
# EG_US                          1  0
# IN_US                          6  0
# US_US                          8  1
#
#
# Payment Failure                       0  1
# Latest shipping address name casing
# lower                                93  8
#
#
# Payment Failure                          1
# Billing address has lengthy unit number
# true                                     1
#
#
# Payment Failure         0
# iOS Mobile Device Name
# Andrew’s iPhone         4
# Beri’s iPad             3
#
#
# Payment Failure                 0
# IP/shipping country codes pair
# CA_US                           2
# NL_US                           2
#
#
# Payment Failure                        0  1
# Android last location neighborhood ID
# 33.61,-84.47                           0  1
# 33.63,-84.49                           0  1
# 35.24,-81.13                           1  0
# 40.70,-73.96                           1  0
#
#
# Payment Failure                       0
# Billing address has forwarding terms
# true                                  1
#
#
# Payment Failure   0   1
# Market ID
# atlanta           2  10
# new-england      55   4
#
#
# Payment Failure               0
# Latest shipping address name
# Micah Blossomgame             1
#
#
# Payment Failure                0   1
# Transaction_payment_gateway
# $stripe                      286  85
#
#
# Payment Failure                 0  1
# Payment method cvv result code
# N                               8  2
# P                               0  1
#
#
# Payment Failure                                      0   1
# Phone number used when user creates an account ...
# S_C                                                 69  18
#
#
# Payment Failure                 0  1
# Latest shipping address region
# GA                              2  1
# RI                              2  0
#
#
# Payment Failure                     0  1
# Billing first and last names match
# true                                3  1
#
#
# Payment Failure        0  1
# Billing name casing
# lower                166  8
# mixed                 17  4
#
#
# Payment Failure                  1
# Transaction_verification_status
# $success                         2
#
#
# Payment Failure                            0  1
# Create account phone number country code
# India                                      1  0
# Italy                                      8  0
# Portugal                                   1  0
# United States                             16  2
#
#
# Payment Failure      0  1
# Latest promotion ID
# FLX-pN9d3            0  2
# LKAIT9               2  0
#
#
# Payment Failure            0
# Shipping name fingerprint
# micah blossomgame          1
#
#
# Payment Failure        0
# Email username casing
# upper                  3
#
#
# Payment Failure  0
# Payment Type
# $prepaid_card    3
#
#
# Payment Failure                           0  1
# Cookie fingerprint
# 5155ea9ae0c860c4572799d97c6a0b30a543a03d  4  1
# b7eca35cad48698bc0548bdc48c8f6c5b39c088d  2  0
# b95c0c01495ca0091915561c93cf445b5093ecec  0  1
#
#
# Payment Failure                                0   1
# Account phone number line and operator type
# S_C                                          201  60
# V_C                                            1   2
# V_V                                            1   0
#
#
# Payment Failure           0    1
# Latest shipping method
# $electronic             570  137
#
#
# Payment Failure                 0  1
# Android Mobile Carrier Country
# Mexico                          0  3
# Spain                           1  0
# United Kingdom                  0  4
#
#
# Payment Failure           0
# Transaction_payment_type
# $prepaid_card             3
#
#
# Payment Failure                                0   1
# Create account phone line and operator type
# S_C                                          157  50
# V_C                                            1   2
# V_V                                            1   0
#
#
# Payment Failure                           0  1
# Host providing this user's email service
# att.net                                   4  1
# gmx.com                                   1  0
# no_mx                                     0  1
#
#
# Payment Failure                    0
# Latest shipping address address 1
# 2660 Fairlane Dr SE                1
# 782 Peachtree St Ne                2
#
#
# Payment Failure                  0   1
# Transaction without page view
# true                           541  98
#
#
# Payment Failure                                  0   1
# Transaction without page view or mobile event
# true                                           254  65
#
#
# Payment Failure                           1
# Browser+IP fingerprint
# 7af1a4d8f3a173c3c2f05b1a2e53f20d2693ed73  1
#
#
# Payment Failure    0  1
# Android Device ID
# 05892bf70761ce42   1  2
# 71c9e1c4ea18a416   1  0
# 7e5610ec57804632   4  0
# d85b5e45bace987c   4  0
#
#
# Payment Failure               1
# Latest shipping address city
# Atlanta                       1
#
#
# Payment Failure   0   1
# Payment type
# ORDER            21   3
# SUBSCRIPTION     28  10
#
#
# Payment Failure           0  1
# Transaction billing city
# Stonecrest                1  1

# %%
set(combined_data['Non-transaction API event without page view'].dropna().unique())
# Out:
# {'true'}
